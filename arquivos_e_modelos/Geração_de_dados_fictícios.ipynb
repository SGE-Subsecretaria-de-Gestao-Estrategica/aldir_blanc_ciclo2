# %% [markdown]
# # Geração de Dados Fictícios - PNAB Ciclo 2 (Fase 1)
#
# ## Objetivo
# Este notebook gera DataFrames fictícios usando Python e Pandas para simular os dados da **Fase 1 (Inscrição)** do Padrão SNIIC - PNAB Ciclo 2.
#
# O objetivo é criar datasets realistas para testes de importação, validação de sistemas e desenvolvimento de módulos de exportação (Cenários 2 e 4 do Guia de Implementação).
#
# Ele cria 7 DataFrames distintos, um para cada entidade da Fase 1:
# 1.  `Agente Individual`
# 2.  `Pessoa Jurídica`
# 3.  `Coletivo Informal`
# 4.  `Proposta de Ação Cultural`
# 5.  `Proposta de Subsídio`
# 6.  `Proposta de Bolsa`
# 7.  `Proposta de Premiação`
#
# ## Metodologia
# O script utiliza as seguintes bibliotecas Python:
# * `pandas` para a criação e estruturação dos DataFrames.
# * `faker` para gerar dados realistas (nomes, CPFs, CNPJs, datas, etc.) em português brasileiro.
# * `requests` para baixar o arquivo de Listas de Valores diretamente do repositório oficial no GitHub.
# * `json` e `random` para ler o arquivo JSON e selecionar aleatoriamente os valores dos vocabulários controlados (ex: Segmento Cultural, Pautas Temáticas).
#
# ## Arquivos de Referência
# Este notebook é baseado nos seguintes documentos oficiais do Padrão de Dados:
#
# 1.  **[Padrão SNIIC para Coleta de Dados - PNAB Ciclo 2](https://github.com/SGE-Subsecretaria-de-Gestao-Estrategica/aldir_blanc_ciclo2/blob/main/README.md)** O documento principal que descreve a política de coleta.
#
# 2.  **[Dicionários da Fase 1](https://github.com/SGE-Subsecretaria-de-Gestao-Estrategica/aldir_blanc_ciclo2/blob/main/dicionario-fase-1.md)** - Define os nomes das colunas (`Nomes formatados`) e os tipos de dados usados neste script.
#
# 3.  **[Listas de Valores (JSON)](https://raw.githubusercontent.com/SGE-Subsecretaria-de-Gestao-Estrategica/aldir_blanc_ciclo2/refs/heads/main/arquivos_e_modelos/lista_de_valores.json)** O arquivo JSON que este script **lê diretamente** para popular os campos de vocabulário controlado.

# %%
import pandas as pd
import random
import json
# !pip install faker
import requests
from faker import Faker
# Out:
# Collecting faker
#   Downloading faker-37.12.0-py3-none-any.whl.metadata (15 kB)
# Requirement already satisfied: tzdata in /usr/local/lib/python3.12/dist-packages (from faker) (2025.2)
# Downloading faker-37.12.0-py3-none-any.whl (2.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 23.2 MB/s eta 0:00:00
# Installing collected packages: faker
# Successfully installed faker-37.12.0

# %%
# Inicializa o Faker para gerar dados em português brasileiro
fake = Faker('pt_BR')

# %%
# --- Carrega as Listas de Valores do URL do GitHub ---
url_json = "https://raw.githubusercontent.com/SGE-Subsecretaria-de-Gestao-Estrategica/aldir_blanc_ciclo2/refs/heads/main/arquivos_e_modelos/lista_de_valores.json"

try:
    response = requests.get(url_json)
    response.raise_for_status()  # Verifica se houve erro no download
    listas_json = response.json()
    print("Arquivo JSON carregado com sucesso do GitHub.")
except requests.exceptions.RequestException as e:
    print(f"ERRO: Não foi possível carregar o arquivo JSON do URL: {e}")
    exit()
except json.JSONDecodeError:
    print("ERRO: O arquivo baixado do URL não é um JSON válido.")
    exit()
# Out:
# Arquivo JSON carregado com sucesso do GitHub.

# %%
listas_json
# Out:
# {'1. Povos e comunidades tradicionais': ['Não pertence a povos ou comunidades tradicionais.',
#   'Andirobeiros',
#   'Apanhadores de flores sempre vivas',
#   'Benzedeiros',
#   'Caatingueiros',
#   'Caboclos',
#   'Caiçaras',
#   'Catadores de mangaba',
#   'Cipozeiros',
#   'Comunidades de fundos e fechos de pasto',
#   'Comunidades quilombolas',
#   'Extrativistas',
#   'Extrativistas costeiros e marinhos',
#   'Faxinalenses',
#   'Geraizeiros',
#   'Ilhéus',
#   'Juventude de povos e comunidades tradicionais',
#   'Morroquianos',
#   'Pantaneiros',
#   'Pescadores artesanais',
#   'Povo pomerano',
#   'Povos ciganos',
#   'Povos e comunidades de terreiro/de matriz africana',
#   'Povos indígenas',
#   'Quebradeiras de coco babaçu',
#   'Raizeiros',
#   'Retireiros do Araguaia',
#   'Ribeirinhos',
#   'Vazanteiros',
#   'Veredeiros'],
#  '2. Gênero': ['Homem cisgênero',
#   'Mulher cisgênero',
#   'Homem trans',
#   'Mulher trans',
#   'Travesti',
#   'Não binário',
#   'Outra',
#   'Prefere não responder'],
#  '3. Orientação sexual': ['Lésbica',
#   'Gay',
#   'Heterossexual',
#   'Bissexual',
#   'Outra',
#   'Prefere não responder'],
#  '4. Cor/Raça/Etnia': ['Branca', 'Preta', 'Amarela', 'Parda', 'Indígena'],
#  '5. Pessoa com deficiência': ['Não',
#   'Sim, Auditiva',
#   'Sim, Física-motora',
#   'Sim, Intelectual',
#   'Sim, Visual',
#   'Sim, Múltipla',
#   'Sim, Transtorno do Espectro Autista',
#   'Sim, outra (especificar)'],
#  '6. Escolaridade': ['Não possui educação formal',
#   'Ensino fundamental incompleto ou equivalente',
#   'Ensino fundamental completo ou equivalente',
#   'Ensino médio incompleto ou equivalente',
#   'Ensino médio completo ou equivalente',
#   'Curso técnico incompleto',
#   'Curso técnico completo',
#   'Ensino superior incompleto ou equivalente',
#   'Ensino superior completo',
#   'Pós-graduação incompleto',
#   'Pós-graduação completo'],
#  '7. Renda média individual (R$)': ['Nenhuma renda',
#   'Até 1 salário mínimo',
#   'De 1 a 3 salários mínimos',
#   'De 3 a 5 salários mínimos',
#   'De 5 a 8 salários mínimos',
#   'De 8 a 10 salários mínimos',
#   'Acima de 10 salários mínimos'],
#  '8. Segmento Cultural': ['Acervos',
#   'Arquivos',
#   'Artes Visuais',
#   'Artesanato',
#   'Audiovisual',
#   'Capoeira',
#   'Circo',
#   'Cultura de Matriz Africana',
#   'Cultura dos Povos Originários',
#   'Culturas Populares e Tradicionais',
#   'Dança',
#   'Design',
#   'Edição e produção editorial',
#   'Festas e Celebrações',
#   'Hip Hop',
#   'Jogos eletrônicos',
#   'Literatura',
#   'Mediação e formação de leitores',
#   'Moda',
#   'Museu',
#   'Música',
#   'Patrimônio Arqueológico',
#   'Patrimônio Cultural Material',
#   'Patrimônio Cultural Imaterial',
#   'Patrimônio Natural',
#   'Performance',
#   'Teatro',
#   'Outros'],
#  '9. Etapas do Ciclo Cultural': ['Criação',
#   'Produção',
#   'Comercialização e Distribuição',
#   'Difusão e Circulação',
#   'Acesso, mediação e fruição',
#   'Formação',
#   'Pesquisa e reflexão',
#   'Proteção e salvaguarda do patrimônio',
#   'Organização e gestão',
#   'Monitoramento e avaliação',
#   'Outra (especificar)'],
#  '10. Pautas Temáticas': ['Não se relaciona a nenhuma pauta temática',
#   'Cultura Alimentar',
#   'Cultura DEF',
#   'Cultura Digital',
#   'Culturas Imigrantes e Refugiadas',
#   'Cultura LGBTQIAPN+',
#   'Cultura, Memória e Direitos Humanos',
#   'Cultura Nerd',
#   'Culturas Periféricas',
#   'Cultura Quilombola',
#   'Culturas Rurais e Agroecológicas',
#   'Culturas Urbanas',
#   'Cultura do Sertão',
#   'Cultura e Acessibilidade',
#   'Cultura e Economia Criativa',
#   'Cultura e Educação',
#   'Cultura e Gênero',
#   'Cultura e Idosos',
#   'Cultura e Infância',
#   'Cultura e Juventude',
#   'Cultura e Meio ambiente',
#   'Cultura e Negritude',
#   'Cultura e Pessoas em Situação de Privação de Liberdade',
#   'Cultura e População de Rua',
#   'Cultura e Povos Ciganos',
#   'Cultura e Saúde',
#   'Cultura e Turismo',
#   'Culturas Indígenas',
#   'Culturas Tradicionais de Matriz Africana',
#   'Outra (especificar)'],
#  '11. Territórios Prioritários': ['Não se aplica',
#   'Área atingida por desastre natural',
#   'Assentamento ou acampamento',
#   'Conjunto ou empreendimento habitacional de interesse social',
#   'Favelas e comunidades urbanas',
#   'Periferia',
#   'Regiões com menor histórico de acesso aos recursos da política pública de cultura',
#   'Regiões com menor índice de Desenvolvimento Humano - IDH',
#   'Sítios de arqueológicos e de patrimônio cultural',
#   'Território de fronteira',
#   'Território de povos e comunidades tradicionais',
#   'Território indígena',
#   'Território rural',
#   'Zona especial de interesse social'],
#  '12. Tipos de Entregas': ['Não aplicável - Premiação cultural',
#   'Não aplicável - Bolsa cultural',
#   'Álbum musical',
#   'Aplicativo / Software',
#   'Apresentação ao vivo / Show',
#   'Aquisição de acervos e bens culturais',
#   'Arte gráfica / Desenho / Gravura / Ilustração',
#   'Artesanato',
#   'Artigo / Ensaio',
#   'Audiolivro',
#   'Aula / Palestra / Conferência',
#   'Blog / Site',
#   'Caderno / Cartilha / Apostila',
#   'Circulação / Turnê',
#   'Coleção',
#   'Congresso / Encontro / Seminário / Simpósio',
#   'Curso / Oficina / Workshop',
#   'Desfile',
#   'Digitalização de acervos',
#   'Livro',
#   'Livro eletrônico (e-Book)',
#   'Ensaio fotográfico',
#   'Escultura',
#   'Espetáculo cênico',
#   'Feira',
#   'Exibição / Exposição',
#   'Festa Popular',
#   'Festival / Mostra',
#   'Filme de curta-metragem',
#   'Filme de longa-metragem',
#   'Filme de média-metragem ou telefilme',
#   'Grafitti/Mural',
#   'Intercâmbio',
#   'Instalação artística / videoarte',
#   'Jogo eletrônico',
#   'Licenciamento',
#   'Manutenção de grupos / iniciativas / espaços culturais',
#   'Melhoria em espaço cultural',
#   'Pesquisa',
#   'Plataforma digital',
#   'Podcast/ Programa de TV ou Rádio',
#   'Residência Artística',
#   'Revista / Jornal / Periódico',
#   'Roteiro de filme ou episódio',
#   'Sarau / Slam',
#   'Série / websérie',
#   'Videoclipe / Album visual',
#   'Outros (especificar)'],
#  '13. Tipos de Espaços e Equipamentos Culturais': ['Arena ou semi arena de apresentações',
#   'Associação Comunitária',
#   'Atelier',
#   'Auditório',
#   'Biblioteca',
#   'Biblioteca Comunitária',
#   'Biblioteca Parque',
#   'Casa da Cultura',
#   'Casa de Espetáculo',
#   'Centro Cultural',
#   'Centro de Convenções',
#   'Centro de convivência',
#   'Centro de Memória e Patrimônio',
#   'Centro de Tradição Regional',
#   'Cinemas, cineclubes e salas de exibição',
#   'Cinemateca',
#   'Circo (inclusive itinerante)',
#   'Escola de arte e cultura',
#   'Escola de samba',
#   'Escola de alimentação e cultura',
#   'Espaço de Leitura',
#   'Espaço Multiuso',
#   'Espaços makers',
#   'Estúdio de audiovisual',
#   'Estúdio de Dança',
#   'Estúdio de Música',
#   'FabLabs',
#   'Galeria e espaços de exposição',
#   'Imóvel patrimonializado',
#   'Laboratórios de Economia Criativa',
#   'Livraria, alfarrábio ou sebo',
#   'Memorial',
#   'Mercados de arte e artesanato',
#   'Museu',
#   'Ponto de Leitura',
#   'Pontos e Pontões de Cultura',
#   'Rádios comunitárias',
#   'Sala de Concerto',
#   'Sambódromo',
#   'Teatro',
#   'Outros (informar qual)'],
#  '14. Recursos Financeiros de Outras Fontes': ['Não, a ação não possui outras fontes de recursos financeiros',
#   'Apoio financeiro municipal',
#   'Apoio financeiro estadual',
#   'Recursos de Lei de Incentivo Municipal',
#   'Recursos de Lei de Incentivo Estadual',
#   'Recursos de Lei de Incentivo Federal',
#   'Patrocínio privado direto',
#   'Patrocínio de instituição internacional',
#   'Doações de Pessoas Físicas',
#   'Doações de Empresas',
#   'Cobrança de ingressos',
#   'Vendas de produtos',
#   'Outros'],
#  '15.1 Acessibilidade arquitetônica': ['Rotas acessíveis, com espaço de manobra para cadeira de rodas',
#   'Piso tátil',
#   'Rampas',
#   'Elevadores adequados para pessoas com deficiência',
#   'Corrimãos e guarda-corpos',
#   'Banheiros femininos e masculinos adaptados para pessoas com deficiência',
#   'Vagas de estacionamento para pessoas com deficiência',
#   'Assentos para pessoas obesas',
#   'Iluminação adequada',
#   'Outra acessibilidade arquitetônica'],
#  '15.2 Acessibilidade comunicacional': ['Língua Brasileira de Sinais - Libras',
#   'Sistema Braille',
#   'Sistema de sinalização ou comunicação tátil',
#   'Audiodescrição',
#   'Legendas',
#   'Linguagem simples',
#   'Textos adaptados para leitores de tela',
#   'Outra acessibilidade comunicacional'],
#  '15.3 Acessibilidade atitudinal': ['Capacitação de equipes atuantes nos projetos culturais',
#   'Contratação de profissionais com deficiência e profissionais especializados em Acessibilidade cultural',
#   'Formação e sensibilização de agentes culturais, público e todos os envolvidos na cadeia produtiva cultural',
#   'Outras medidas que visem a eliminação de atitudes capacitistas.']}

# %%
# --- Listas de Valores (Valores Curtos e Específicos, não presentes no JSON) ---
sim_nao_sei = ['Sim', 'Não', 'Não sei']
modalidade_reserva = [
    'Proposta selecionada em ampla concorrência', 'Reserva de vagas para pessoas negras',
    'Reserva de vagas para pessoas indígenas', 'Reserva de vagas para pessoas com deficiência',
    'Reserva de vagas para outros grupos'
]
formato_acao = [
    'Presencialmente em local fixo', 'Presencialmente itinerante', 'Remotamente/Online',
    'Em formato híbrido', 'Outros', 'Não aplicável'
]
porte_espaco = [
    'Pequeno: até 499 m²', 'Média: de 500 m² a 1999 m²',
    'Grande: acima de 2000 m²', 'Não se aplica'
]
categoria_atividades_bolsa = [
    'Pesquisa/Formação em educação patrimonial', 'Pesquisa/Formação artístico-cultural ou técnica',
    'Pesquisa/Formação em política e gestão cultural', 'Difusão/circulação artístico-cultural',
    'Participação em eventos', 'Intercâmbios ou residências artísticas', 'Outros (especificar)'
]
ambito_bolsa = ['Nacional', 'Internacional', 'Ambos (nacional e internacional)']

# %%
# --- Funções de Geração de Dados (Usando o JSON carregado) ---

def generate_agente_individual(num_rows):
    data = []
    for _ in range(num_rows):
        tipo_agente = random.choice(['Pessoa física', 'Microempreendedor individual - MEI'])
        record = {
            'tipo_agente_individual': tipo_agente,
            'cpf': fake.cpf(),
            'cnpj_mei': fake.cnpj() if tipo_agente == 'Microempreendedor individual - MEI' else None,
            'nome_completo': fake.name(),
            'nome_social_artistico': random.choice([fake.name(), None]),
            'data_nascimento': fake.date_of_birth(minimum_age=18, maximum_age=90).strftime('%d/%m/%Y'),
            'email': fake.email(),
            'telefone': fake.phone_number(),
            'cep': fake.postcode(),
            'uf_residencia': fake.state_abbr(),
            'municipio_residencia': fake.city(),
            'endereco_completo': fake.address(),
            'comunidade_tradicional': ", ".join(random.sample(listas_json["1. Povos e comunidades tradicionais"], k=random.randint(1, 2))),
            'mestre_cultura_popular': random.choice([True, False]),
            'genero': random.choice(listas_json["2. Gênero"]),
            'orientacao_sexual': random.choice(listas_json["3. Orientação sexual"]),
            'cor_raca': random.choice(listas_json["4. Cor/Raça/Etnia"]),
            'pessoa_com_deficiencia': ", ".join(random.sample(listas_json["5. Pessoa com deficiência"], k=random.randint(1, 2))),
            'escolaridade': random.choice(listas_json["6. Escolaridade"]),
            'faixa_renda': random.choice(listas_json["7. Renda média individual (R$)"]),
            'anos_experiencia_cultural': random.randint(0, 50),
            'acessou_recursos_5anos': random.choice(sim_nao_sei)
        }
        data.append(record)
    return pd.DataFrame(data)

def generate_pessoa_juridica(num_rows):
    data = []
    for _ in range(num_rows):
        record = {
            'tipo_pessoa_juridica': random.choice(['Pessoa Jurídica com fins lucrativos (empresas)', 'Pessoa Jurídica sem fins lucrativos (OSCs)']),
            'cnpj': fake.cnpj(),
            'razao_social': fake.company(),
            'nome_fantasia': random.choice([fake.company(), None]),
            'data_fundacao': fake.date_of_birth(minimum_age=1, maximum_age=100).strftime('%d/%m/%Y'),
            'nome_representante_legal': fake.name(),
            'cpf_representante_legal': fake.cpf(),
            'email_organizacao': fake.email(),
            'telefone_organizacao': fake.phone_number(),
            'cep_sede': fake.postcode(),
            'endereco_sede': fake.address(),
            'municipio_sede': fake.city(),
            'uf_sede': fake.state_abbr(),
            'anos_atuacao_cultural': random.randint(1, 100),
            'acessou_recursos_5anos_org': random.choice(sim_nao_sei)
        }
        data.append(record)
    return pd.DataFrame(data)

def generate_coletivo_informal(num_rows):
    data = []
    for _ in range(num_rows):
        record = {
            'nome_grupo_coletivo': fake.company(),
            'qtd_membros_coletivo': random.randint(2, 50),
            'nome_representante_coletivo': fake.name(),
            'cpf_representante_coletivo': fake.cpf(),
            'email_coletivo': fake.email(),
            'telefone_coletivo': fake.phone_number(),
            'cep_coletivo': fake.postcode(),
            'endereco_coletivo': fake.address(),
            'municipio_coletivo': fake.city(),
            'uf_coletivo': fake.state_abbr(),
            'anos_atuacao_coletivo': random.randint(1, 50),
            'acessou_recursos_5anos_col': random.choice(sim_nao_sei)
        }
        data.append(record)
    return pd.DataFrame(data)

def generate_proposta_acao_cultural(num_rows):
    data = []
    for _ in range(num_rows):
        record = {
            'id_edital': f"Edital-2025-{random.randint(100, 999)}",
            'selecionado_cotas': random.choice(modalidade_reserva),
            'titulo_proposta': fake.catch_phrase(),
            'resumo_proposta': fake.paragraph(nb_sentences=5),
            'valor_proposta': round(random.uniform(5000, 100000), 2),
            'formato_proposta': random.choice(formato_acao),
            'cep_local_realizacao': fake.postcode(),
            'qtd_pessoas_remuneradas': random.randint(1, 20),
            'segmento_cultural_principal': random.choice(listas_json["8. Segmento Cultural"]),
            'etapa_ciclo_cultural_principal': random.choice(listas_json["9. Etapas do Ciclo Cultural"]),
            'pauta_tematica_principal': random.choice(listas_json["10. Pautas Temáticas"]),
            'atua_territorio_prioritario': ", ".join(random.sample(listas_json["11. Territórios Prioritários"], k=random.randint(1, 3))),
            'entregas_previstas': ", ".join(random.sample(listas_json["12. Tipos de Entregas"], k=random.randint(1, 3)))
        }
        data.append(record)
    return pd.DataFrame(data)

def generate_proposta_subsidio(num_rows):
    data = []
    for _ in range(num_rows):
        record = {
            'id_edital': f"Edital-Subsidio-2025-{random.randint(100, 999)}",
            'selecionado_cotas_espaco': random.choice(modalidade_reserva),
            'nome_espaco_cultural': fake.company(),
            'cep_espaco': fake.postcode(),
            'tipo_espaco_cultural': ", ".join(random.sample(listas_json["13. Tipos de Espaços e Equipamentos Culturais"], k=random.randint(1, 3))),
            'porte_espaco_cultural': random.choice(porte_espaco),
            'segmentos_espaco_cultural': ", ".join(random.sample(listas_json["8. Segmento Cultural"], k=random.randint(1, 3))),
            'espaco_territorio_prioritario': ", ".join(random.sample(listas_json["11. Territórios Prioritários"], k=random.randint(1, 2))),
            'anos_existencia_espaco': random.randint(1, 70),
            'acessou_recursos_5anos_esp': random.choice(sim_nao_sei),
            'valor_total_subsidio': round(random.uniform(10000, 50000), 2),
            'qtd_parcelas_subsidio': random.randint(1, 12)
        }
        data.append(record)
    return pd.DataFrame(data)

def generate_proposta_bolsa(num_rows):
    data = []
    for _ in range(num_rows):
        gera_entrega = random.choice([True, False])
        ambito = random.choice(ambito_bolsa)
        record = {
            'id_edital': f"Edital-Bolsa-2025-{random.randint(100, 999)}",
            'selecionado_cotas': random.choice(modalidade_reserva),
            'titulo_proposta': fake.catch_phrase(),
            'resumo_proposta': fake.paragraph(nb_sentences=4),
            'valor_proposta': round(random.uniform(5000, 30000), 2),
            'qtd_pessoas_remuneradas': random.randint(1, 3),
            'segmento_cultural_principal': random.choice(listas_json["8. Segmento Cultural"]),
            'pauta_tematica_principal': random.choice(listas_json["10. Pautas Temáticas"]),
            'categoria_atividades_bolsa': random.choice(categoria_atividades_bolsa),
            'ambito_bolsa': ambito,
            'destino_nacional_bolsa': fake.city() if ambito in ['Nacional', 'Ambos (nacional e internacional)'] else None,
            'destino_internacional_bolsa': fake.country() if ambito in ['Internacional', 'Ambos (nacional e internacional)'] else None,
            'gera_produto_entrega': gera_entrega,
            'tipo_entrega_prevista': random.choice(listas_json["12. Tipos de Entregas"]) if gera_entrega else None
        }
        data.append(record)
    return pd.DataFrame(data)

def generate_proposta_premiacao(num_rows):
    data = []
    for _ in range(num_rows):
        record = {
            'id_edital': f"Edital-Premio-2025-{random.randint(100, 999)}",
            'selecionado_cotas': random.choice(modalidade_reserva),
            'valor_premiacao': round(random.uniform(1000, 20000), 2),
            'segmento_cultural_principal': random.choice(listas_json["8. Segmento Cultural"]),
            'pauta_tematica_principal': random.choice(listas_json["10. Pautas Temáticas"]),
            'atua_territorio_prioritario': ", ".join(random.sample(listas_json["11. Territórios Prioritários"], k=random.randint(1, 2)))
        }
        data.append(record)
    return pd.DataFrame(data)

# %%
NUM_ROWS = 50  # Define quantos registros fictícios gerar por entidade

# 1. Gerar todos os DataFrames
df_agente_individual = generate_agente_individual(NUM_ROWS)
df_pessoa_juridica = generate_pessoa_juridica(NUM_ROWS)
df_coletivo_informal = generate_coletivo_informal(NUM_ROWS)
df_proposta_acao = generate_proposta_acao_cultural(NUM_ROWS)
df_proposta_subsidio = generate_proposta_subsidio(NUM_ROWS)
df_proposta_bolsa = generate_proposta_bolsa(NUM_ROWS)
df_proposta_premiacao = generate_proposta_premiacao(NUM_ROWS)

# 2. Salvar todos em CSV
# Usar encoding 'utf-8-sig' garante compatibilidade com Excel (acentos)
df_agente_individual.to_csv("fase1_agente_individual.csv", index=False, encoding='utf-8-sig')
df_pessoa_juridica.to_csv("fase1_pessoa_juridica.csv", index=False, encoding='utf-8-sig')
df_coletivo_informal.to_csv("fase1_coletivo_informal.csv", index=False, encoding='utf-8-sig')
df_proposta_acao.to_csv("fase1_proposta_acao_cultural.csv", index=False, encoding='utf-8-sig')
df_proposta_subsidio.to_csv("fase1_proposta_subsidio.csv", index=False, encoding='utf-8-sig')
df_proposta_bolsa.to_csv("fase1_proposta_bolsa.csv", index=False, encoding='utf-8-sig')
df_proposta_premiacao.to_csv("fase1_proposta_premiacao.csv", index=False, encoding='utf-8-sig')

print("Todos os 7 arquivos CSV da Fase 1 foram gerados com sucesso.")
# Out:
# Todos os 7 arquivos CSV da Fase 1 foram gerados com sucesso.

# %%
df_agente_individual
# Out:
#                 tipo_agente_individual             cpf            cnpj_mei  \
# 0                        Pessoa física  824.953.160-42                None
# 1   Microempreendedor individual - MEI  209.674.135-16  63.809.572/0001-36
# 2   Microempreendedor individual - MEI  087.963.524-00  25.876.093/0001-43
# 3   Microempreendedor individual - MEI  324.689.571-64  56.984.103/0001-98
# 4   Microempreendedor individual - MEI  836.250.719-59  26.801.374/0001-08
# 5                        Pessoa física  396.217.854-64                None
# 6                        Pessoa física  451.376.928-91                None
# 7   Microempreendedor individual - MEI  674.219.058-20  87.610.293/0001-07
# 8                        Pessoa física  082.935.761-03                None
# 9   Microempreendedor individual - MEI  178.459.230-79  53.186.479/0001-69
# 10                       Pessoa física  419.738.625-73                None
# 11                       Pessoa física  259.741.068-49                None
# 12                       Pessoa física  465.190.738-57                None
# 13                       Pessoa física  692.715.384-55                None
# 14                       Pessoa física  429.013.785-79                None
# 15                       Pessoa física  750.694.312-34                None
# 16  Microempreendedor individual - MEI  016.435.892-70  68.125.049/0001-04
# 17                       Pessoa física  924.381.506-70                None
# 18                       Pessoa física  103.458.927-04                None
# 19                       Pessoa física  372.961.085-68                None
# 20                       Pessoa física  305.642.987-00                None
# 21                       Pessoa física  690.821.345-51                None
# 22  Microempreendedor individual - MEI  582.397.061-77  31.057.692/0001-38
# 23                       Pessoa física  329.176.504-43                None
# 24                       Pessoa física  815.902.764-85                None
# 25                       Pessoa física  967.482.135-09                None
# 26                       Pessoa física  634.872.015-26                None
# 27                       Pessoa física  819.304.567-00                None
# 28                       Pessoa física  016.978.532-77                None
# 29                       Pessoa física  017.594.863-10                None
# 30  Microempreendedor individual - MEI  394.876.250-38  19.650.427/0001-63
# 31                       Pessoa física  842.036.719-22                None
# 32  Microempreendedor individual - MEI  715.089.362-77  16.347.520/0001-05
# 33  Microempreendedor individual - MEI  352.749.810-97  64.083.721/0001-95
# 34  Microempreendedor individual - MEI  561.798.024-67  40.732.856/0001-76
# 35  Microempreendedor individual - MEI  913.546.780-01  36.015.749/0001-50
# 36  Microempreendedor individual - MEI  283.967.514-55  68.241.907/0001-86
# 37  Microempreendedor individual - MEI  765.821.930-40  97.520.384/0001-05
# 38                       Pessoa física  597.012.463-06                None
# 39  Microempreendedor individual - MEI  490.736.518-75  31.586.420/0001-25
# 40                       Pessoa física  327.460.591-34                None
# 41  Microempreendedor individual - MEI  514.370.692-07  40.697.218/0001-61
# 42  Microempreendedor individual - MEI  910.548.372-79  80.176.435/0001-20
# 43  Microempreendedor individual - MEI  860.725.391-30  89.072.345/0001-64
# 44  Microempreendedor individual - MEI  021.534.796-06  21.793.084/0001-38
# 45                       Pessoa física  740.968.513-10                None
# 46  Microempreendedor individual - MEI  780.693.254-29  59.162.347/0001-83
# 47  Microempreendedor individual - MEI  820.167.539-86  26.173.958/0001-78
# 48  Microempreendedor individual - MEI  510.984.627-85  61.029.483/0001-41
# 49  Microempreendedor individual - MEI  618.073.425-90  80.265.731/0001-06
#
#                  nome_completo  nome_social_artistico data_nascimento  \
# 0            Maria Liz da Rosa          Juliana Brito      04/11/1964
# 1                 Julia Novaes   Luiz Henrique Vargas      03/08/2001
# 2                 Bella Fogaça          Cauã Oliveira      01/09/1942
# 3                Luigi Sampaio                   None      25/07/1995
# 4            Sra. Rebeca Silva       Dra. Joana Nunes      14/03/2005
# 5         João Gabriel Azevedo                   None      19/09/1969
# 6               Danilo Marques           Sarah Farias      03/08/1978
# 7           Maria Luiza Fogaça          Lunna Almeida      11/10/1975
# 8            Dra. Maitê Garcia                   None      07/06/1939
# 9                  Allana Rios                   None      02/03/1953
# 10           João Miguel Silva      Ana Laura Azevedo      25/10/1991
# 11          Dra. Helena Borges   Luiz Fernando Novais      25/03/1991
# 12                Ísis Freitas          Ágatha Farias      18/11/1990
# 13               Maysa Martins                   None      11/03/1997
# 14               Yan Fernandes       Hadassa da Cunha      10/03/1975
# 15         Luiz Henrique Jesus          Kamilly Moura      13/05/1941
# 16              Isaac Nogueira                   None      26/07/1936
# 17              Isadora Borges             Caio Brito      15/05/1973
# 18          Enzo Gabriel Alves       Sr. Pedro Novaes      21/09/1938
# 19                 Eloah Sales        Cecilia Martins      10/09/2004
# 20             Rafael Carvalho          Vitor Pereira      21/06/1993
# 21                Enzo da Mata           Bruno Garcia      13/07/1993
# 22             Kamilly Pimenta            Cauê Fogaça      26/05/2003
# 23                 José Duarte                   None      15/12/1973
# 24              Sarah Cassiano                   None      05/01/2004
# 25               Asafe Pimenta        Caroline Duarte      31/08/1960
# 26           Julia Vasconcelos                   None      16/11/1983
# 27                Evelyn Nunes                   None      02/04/1953
# 28                 Levi Vargas                   None      17/03/1983
# 29  Marcos Vinicius Nascimento                   None      07/08/1989
# 30               Isis Teixeira                   None      01/08/1991
# 31               Aurora Borges                   None      06/04/1977
# 32              Thiago Freitas             Theo Jesus      28/11/1964
# 33                Esther Cunha           Vitória Rios      10/05/1989
# 34              Bárbara Vargas                   None      16/03/1980
# 35            Danilo Gonçalves                   None      17/05/1955
# 36              Maria Oliveira                   None      14/05/2001
# 37          Luiz Otávio Aragão          Lucca Rezende      18/09/1981
# 38             Emanuel da Cruz        Antonella Rocha      07/12/1978
# 39          Luiz Gustavo Souza          Luiza Rezende      13/11/1999
# 40              Helena Machado       Leonardo Peixoto      01/10/2006
# 41        Sra. Lavínia Costela                   None      10/08/1951
# 42                 Laura Rocha                   None      18/05/1967
# 43                Joana Moraes          Marcelo Porto      27/02/1999
# 44     Dr. Benicio Vasconcelos                   None      31/01/1950
# 45               Isabella Dias                   None      25/03/1975
# 46              Hellena Câmara  Maria Cecília Pereira      10/07/1987
# 47    Srta. Maria Luísa Guerra           Isaac da Paz      23/03/1981
# 48          Asafe da Conceição                   None      04/12/1940
# 49       Pedro Miguel Nogueira                   None      19/04/1960
#
#                                   email             telefone        cep  \
# 0                   julia55@example.net  +55 (084) 7812 8248   20681470
# 1             vianavinicius@example.net  +55 (011) 6581 1600  43859-779
# 2       novaesmaria-vitoria@example.net      (031) 4184-8232   47619008
# 3        pedro-miguelvieira@example.com      (071) 6865-6527  52206-306
# 4         sousaana-carolina@example.org         11 0860 6899   64201717
# 5                egoncalves@example.net     +55 84 2870 1966  99305-997
# 6           lucas-gabriel07@example.org      (041) 9817-1786   81377975
# 7                    kramos@example.org  +55 (011) 6114-9126  82152-318
# 8                    jlopes@example.net     +55 61 3664 0444  93212-581
# 9              novaesrafael@example.com      (051) 1818 7246  46833-943
# 10                abreueloa@example.net     +55 11 0243 8771   51547578
# 11  maria-helenaalbuquerque@example.com     +55 61 7467 1769  61134-070
# 12            allanaandrade@example.net     +55 51 0790 9227   87638644
# 13                   raul40@example.net         81 7751 0585   32083648
# 14            sophieribeiro@example.net      (084) 6223-9096   90754689
# 15         goncalvesmirella@example.net  +55 (011) 9431-4240  92317-668
# 16                mariane75@example.net         51 5359 4737  10657-506
# 17           lopesfrancisco@example.com      (051) 8820-6440  12227-738
# 18        da-pazpedro-lucas@example.com         31 1496 4051  63955-574
# 19        sabrinanascimento@example.net     +55 51 4279 6665  25381-034
# 20                  josue51@example.org         81 6372-2520   82724517
# 21           silveiraagatha@example.net      (084) 0191-3920  59415-998
# 22                 cmachado@example.com     +55 81 7673 9355  20731-742
# 23                   ulopes@example.com        0800 160 7996   46557079
# 24                 melina94@example.com  +55 (021) 2970 8698   22821572
# 25                   isis52@example.com  +55 (051) 6852 3425  90101-428
# 26          henriquefreitas@example.net      (071) 2905 0667  74508-652
# 27   freitasanthony-gabriel@example.com         41 9985 1785   10229840
# 28                  nmacedo@example.net     +55 31 4618-7651  64861-060
# 29                 mpereira@example.com      (061) 6800 9192  47670-081
# 30                  tsantos@example.net  +55 (081) 4797-8038   01777677
# 31            andradekaique@example.org        0300-324-2250   49508666
# 32           renanaparecida@example.org      (084) 3441 0323  40407-839
# 33            camargolorena@example.com  +55 (084) 8005-0906  18012-185
# 34             biancacastro@example.com        0800 538 1922   83360251
# 35          rezendegabriela@example.org  +55 (041) 7209 8398  84197-256
# 36                 miguel30@example.com  +55 (071) 0335-2591  29645-071
# 37               valentim65@example.org  +55 (071) 3696 9106   64123691
# 38             pimentabella@example.net         81 6498 7024  90486-261
# 39                   upinto@example.org         41 6199-3740   78324032
# 40             salesvicente@example.org         84 5002-9332  17062-657
# 41           rezendeana-liz@example.org      (081) 1102 0130   49915923
# 42                 nandrade@example.net  +55 (011) 8038-5802  67214-304
# 43      ana-liviacavalcante@example.net     +55 71 4348-1910   06578258
# 44         aparecidaclarice@example.com  +55 (011) 9682 0304   34708214
# 45         emanuellymachado@example.com  +55 (041) 2642-0278   88415436
# 46            maria-laura79@example.net  +55 (031) 9538 0752  18529-624
# 47    britogustavo-henrique@example.net         84 0414-6452   33389956
# 48    vitor-gabrielteixeira@example.org  +55 (041) 3362 8116   31573601
# 49                    yan10@example.org        0900 314 7721  05526-968
#
#    uf_residencia  ...                             comunidade_tradicional  \
# 0             RJ  ...                                        Ribeirinhos
# 1             RN  ...                     Ilhéus, Retireiros do Araguaia
# 2             MG  ...                               Veredeiros, Caiçaras
# 3             RJ  ...                                    Povos indígenas
# 4             AM  ...  Juventude de povos e comunidades tradicionais,...
# 5             MG  ...  Comunidades de fundos e fechos de pasto, Vered...
# 6             AM  ...  Ribeirinhos, Povos e comunidades de terreiro/d...
# 7             ES  ...                                        Pantaneiros
# 8             MS  ...  Povos e comunidades de terreiro/de matriz afri...
# 9             RS  ...                            Povo pomerano, Caboclos
# 10            AC  ...  Faxinalenses, Povos e comunidades de terreiro/...
# 11            GO  ...                                        Benzedeiros
# 12            MA  ...                              Cipozeiros, Raizeiros
# 13            PR  ...                        Morroquianos, Povos ciganos
# 14            RJ  ...                                      Caatingueiros
# 15            AC  ...                                    Povos indígenas
# 16            CE  ...                             Retireiros do Araguaia
# 17            SE  ...                            Extrativistas, Caiçaras
# 18            RN  ...                           Vazanteiros, Benzedeiros
# 19            GO  ...         Quebradeiras de coco babaçu, Povo pomerano
# 20            RO  ...                                        Vazanteiros
# 21            DF  ...                              Caiçaras, Geraizeiros
# 22            MS  ...    Ilhéus, Comunidades de fundos e fechos de pasto
# 23            PI  ...                                      Povo pomerano
# 24            AC  ...                                        Benzedeiros
# 25            AM  ...    Benzedeiros, Apanhadores de flores sempre vivas
# 26            CE  ...  Não pertence a povos ou comunidades tradicionais.
# 27            RR  ...                                      Extrativistas
# 28            SP  ...                                          Raizeiros
# 29            SP  ...    Geraizeiros, Extrativistas costeiros e marinhos
# 30            TO  ...                        Quebradeiras de coco babaçu
# 31            MT  ...                                           Caiçaras
# 32            PA  ...                          Veredeiros, Extrativistas
# 33            SP  ...                 Apanhadores de flores sempre vivas
# 34            SE  ...                                        Pantaneiros
# 35            RO  ...               Andirobeiros, Retireiros do Araguaia
# 36            MT  ...    Comunidades quilombolas, Retireiros do Araguaia
# 37            PI  ...              Faxinalenses, Comunidades quilombolas
# 38            PR  ...                            Povos indígenas, Ilhéus
# 39            RJ  ...                                          Raizeiros
# 40            MT  ...                                           Caiçaras
# 41            AL  ...                           Raizeiros, Caatingueiros
# 42            PA  ...                          Veredeiros, Caatingueiros
# 43            MA  ...                          Caiçaras, Povos indígenas
# 44            MA  ...                Pantaneiros, Retireiros do Araguaia
# 45            MG  ...  Povos e comunidades de terreiro/de matriz afri...
# 46            PB  ...                                       Faxinalenses
# 47            MS  ...                        Caatingueiros, Andirobeiros
# 48            RR  ...  Retireiros do Araguaia, Extrativistas costeiro...
# 49            AL  ...                                       Morroquianos
#
#    mestre_cultura_popular                 genero      orientacao_sexual  \
# 0                    True               Travesti          Heterossexual
# 1                    True           Mulher trans              Bissexual
# 2                   False  Prefere não responder  Prefere não responder
# 3                    True            Não binário          Heterossexual
# 4                    True               Travesti                Lésbica
# 5                   False            Homem trans                  Outra
# 6                    True       Mulher cisgênero          Heterossexual
# 7                   False            Não binário                    Gay
# 8                   False            Homem trans                Lésbica
# 9                    True           Mulher trans                    Gay
# 10                   True        Homem cisgênero              Bissexual
# 11                   True            Homem trans                Lésbica
# 12                   True                  Outra              Bissexual
# 13                  False               Travesti                Lésbica
# 14                  False            Homem trans  Prefere não responder
# 15                   True            Não binário  Prefere não responder
# 16                  False       Mulher cisgênero                Lésbica
# 17                   True           Mulher trans                    Gay
# 18                  False                  Outra  Prefere não responder
# 19                  False                  Outra              Bissexual
# 20                   True       Mulher cisgênero                Lésbica
# 21                   True            Não binário  Prefere não responder
# 22                   True            Não binário                    Gay
# 23                   True       Mulher cisgênero                  Outra
# 24                  False  Prefere não responder              Bissexual
# 25                   True                  Outra                  Outra
# 26                  False                  Outra          Heterossexual
# 27                   True  Prefere não responder              Bissexual
# 28                   True               Travesti                    Gay
# 29                  False            Não binário              Bissexual
# 30                  False            Homem trans                    Gay
# 31                  False  Prefere não responder                    Gay
# 32                   True       Mulher cisgênero              Bissexual
# 33                  False               Travesti          Heterossexual
# 34                  False            Homem trans          Heterossexual
# 35                   True  Prefere não responder          Heterossexual
# 36                   True       Mulher cisgênero                Lésbica
# 37                   True  Prefere não responder          Heterossexual
# 38                   True  Prefere não responder  Prefere não responder
# 39                  False                  Outra              Bissexual
# 40                  False       Mulher cisgênero              Bissexual
# 41                  False            Homem trans                    Gay
# 42                   True               Travesti                  Outra
# 43                   True            Homem trans                    Gay
# 44                   True                  Outra                    Gay
# 45                   True  Prefere não responder                    Gay
# 46                   True            Não binário              Bissexual
# 47                   True           Mulher trans  Prefere não responder
# 48                  False       Mulher cisgênero              Bissexual
# 49                  False               Travesti  Prefere não responder
#
#     cor_raca                             pessoa_com_deficiencia  \
# 0     Branca                    Sim, Múltipla, Sim, Intelectual
# 1    Amarela                         Sim, Visual, Sim, Múltipla
# 2      Preta            Sim, Múltipla, Sim, outra (especificar)
# 3    Amarela                                        Sim, Visual
# 4      Preta  Sim, outra (especificar), Sim, Transtorno do E...
# 5      Preta  Sim, Física-motora, Sim, Transtorno do Espectr...
# 6     Branca                           Sim, outra (especificar)
# 7    Amarela           Não, Sim, Transtorno do Espectro Autista
# 8      Parda                                   Sim, Intelectual
# 9     Branca                                 Sim, Múltipla, Não
# 10     Preta                                                Não
# 11    Branca  Sim, Física-motora, Sim, Transtorno do Espectr...
# 12    Branca               Sim, Física-motora, Sim, Intelectual
# 13     Parda                                                Não
# 14   Amarela                       Sim, Auditiva, Sim, Múltipla
# 15     Parda                           Sim, outra (especificar)
# 16     Parda                  Sim, Auditiva, Sim, Física-motora
# 17   Amarela                                        Sim, Visual
# 18   Amarela           Não, Sim, Transtorno do Espectro Autista
# 19     Parda                           Sim, outra (especificar)
# 20    Branca                      Sim, Intelectual, Sim, Visual
# 21     Parda                Sim, Transtorno do Espectro Autista
# 22     Preta   Sim, Transtorno do Espectro Autista, Sim, Visual
# 23   Amarela                                 Sim, Física-motora
# 24  Indígena                                        Sim, Visual
# 25     Preta                                   Sim, Intelectual
# 26     Parda                         Sim, Visual, Sim, Múltipla
# 27  Indígena            Sim, Múltipla, Sim, outra (especificar)
# 28     Parda                                 Sim, Múltipla, Não
# 29    Branca            Sim, Auditiva, Sim, outra (especificar)
# 30     Preta                                   Sim, Intelectual
# 31   Amarela                                      Sim, Múltipla
# 32  Indígena   Sim, Transtorno do Espectro Autista, Sim, Visual
# 33  Indígena                                 Sim, Múltipla, Não
# 34  Indígena                                      Sim, Auditiva
# 35     Parda                           Sim, outra (especificar)
# 36     Parda           Sim, Transtorno do Espectro Autista, Não
# 37   Amarela                                      Sim, Múltipla
# 38    Branca              Sim, outra (especificar), Sim, Visual
# 39  Indígena                                      Sim, Auditiva
# 40     Preta                                   Sim, Intelectual
# 41  Indígena                                   Sim, Intelectual
# 42     Parda                    Sim, Intelectual, Sim, Auditiva
# 43     Preta                                 Sim, Física-motora
# 44  Indígena  Sim, Auditiva, Sim, Transtorno do Espectro Aut...
# 45  Indígena                                                Não
# 46    Branca                                 Sim, Múltipla, Não
# 47  Indígena                                        Sim, Visual
# 48     Parda  Sim, Múltipla, Sim, Transtorno do Espectro Aut...
# 49     Preta                            Não, Sim, Física-motora
#
#                                     escolaridade  \
# 0      Ensino superior incompleto ou equivalente
# 1     Ensino fundamental completo ou equivalente
# 2           Ensino médio completo ou equivalente
# 3                       Curso técnico incompleto
# 4                       Pós-graduação incompleto
# 5      Ensino superior incompleto ou equivalente
# 6                     Não possui educação formal
# 7         Ensino médio incompleto ou equivalente
# 8                       Ensino superior completo
# 9   Ensino fundamental incompleto ou equivalente
# 10                      Curso técnico incompleto
# 11  Ensino fundamental incompleto ou equivalente
# 12                        Pós-graduação completo
# 13                      Pós-graduação incompleto
# 14          Ensino médio completo ou equivalente
# 15                        Pós-graduação completo
# 16     Ensino superior incompleto ou equivalente
# 17                      Pós-graduação incompleto
# 18        Ensino médio incompleto ou equivalente
# 19        Ensino médio incompleto ou equivalente
# 20                    Não possui educação formal
# 21          Ensino médio completo ou equivalente
# 22                      Pós-graduação incompleto
# 23                    Não possui educação formal
# 24                      Pós-graduação incompleto
# 25                      Ensino superior completo
# 26    Ensino fundamental completo ou equivalente
# 27                      Ensino superior completo
# 28                      Ensino superior completo
# 29                      Pós-graduação incompleto
# 30                      Curso técnico incompleto
# 31                      Pós-graduação incompleto
# 32                      Ensino superior completo
# 33                        Curso técnico completo
# 34                    Não possui educação formal
# 35  Ensino fundamental incompleto ou equivalente
# 36  Ensino fundamental incompleto ou equivalente
# 37                    Não possui educação formal
# 38    Ensino fundamental completo ou equivalente
# 39                    Não possui educação formal
# 40          Ensino médio completo ou equivalente
# 41                      Ensino superior completo
# 42                    Não possui educação formal
# 43          Ensino médio completo ou equivalente
# 44                    Não possui educação formal
# 45                      Ensino superior completo
# 46    Ensino fundamental completo ou equivalente
# 47  Ensino fundamental incompleto ou equivalente
# 48    Ensino fundamental completo ou equivalente
# 49    Ensino fundamental completo ou equivalente
#
#                      faixa_renda anos_experiencia_cultural  \
# 0   Acima de 10 salários mínimos                         5
# 1      De 5 a 8 salários mínimos                        19
# 2     De 8 a 10 salários mínimos                        38
# 3                  Nenhuma renda                        23
# 4   Acima de 10 salários mínimos                        20
# 5   Acima de 10 salários mínimos                         2
# 6           Até 1 salário mínimo                        21
# 7      De 5 a 8 salários mínimos                        31
# 8           Até 1 salário mínimo                         9
# 9   Acima de 10 salários mínimos                        46
# 10     De 5 a 8 salários mínimos                        47
# 11  Acima de 10 salários mínimos                         8
# 12  Acima de 10 salários mínimos                        24
# 13  Acima de 10 salários mínimos                        43
# 14     De 5 a 8 salários mínimos                        45
# 15                 Nenhuma renda                        37
# 16          Até 1 salário mínimo                        27
# 17    De 8 a 10 salários mínimos                        44
# 18  Acima de 10 salários mínimos                        11
# 19     De 3 a 5 salários mínimos                         3
# 20  Acima de 10 salários mínimos                         4
# 21     De 5 a 8 salários mínimos                        36
# 22                 Nenhuma renda                        37
# 23                 Nenhuma renda                        42
# 24          Até 1 salário mínimo                        44
# 25     De 5 a 8 salários mínimos                        38
# 26          Até 1 salário mínimo                        33
# 27  Acima de 10 salários mínimos                        24
# 28     De 3 a 5 salários mínimos                        11
# 29    De 8 a 10 salários mínimos                         5
# 30     De 5 a 8 salários mínimos                        46
# 31    De 8 a 10 salários mínimos                        12
# 32  Acima de 10 salários mínimos                        23
# 33          Até 1 salário mínimo                        14
# 34     De 5 a 8 salários mínimos                        10
# 35                 Nenhuma renda                        19
# 36     De 3 a 5 salários mínimos                        22
# 37     De 5 a 8 salários mínimos                        21
# 38          Até 1 salário mínimo                        29
# 39  Acima de 10 salários mínimos                        37
# 40     De 5 a 8 salários mínimos                        28
# 41     De 5 a 8 salários mínimos                        18
# 42    De 8 a 10 salários mínimos                        10
# 43  Acima de 10 salários mínimos                        27
# 44          Até 1 salário mínimo                         1
# 45     De 3 a 5 salários mínimos                        41
# 46     De 1 a 3 salários mínimos                         6
# 47     De 1 a 3 salários mínimos                        45
# 48     De 5 a 8 salários mínimos                        17
# 49  Acima de 10 salários mínimos                        27
#
#    acessou_recursos_5anos
# 0                     Sim
# 1                     Sim
# 2                 Não sei
# 3                     Sim
# 4                     Sim
# 5                 Não sei
# 6                     Não
# 7                     Não
# 8                     Sim
# 9                     Não
# 10                    Sim
# 11                Não sei
# 12                    Não
# 13                    Sim
# 14                Não sei
# 15                Não sei
# 16                    Não
# 17                    Não
# 18                    Não
# 19                    Não
# 20                    Sim
# 21                Não sei
# 22                Não sei
# 23                    Sim
# 24                Não sei
# 25                    Sim
# 26                    Sim
# 27                    Sim
# 28                Não sei
# 29                    Sim
# 30                    Sim
# 31                Não sei
# 32                Não sei
# 33                    Sim
# 34                Não sei
# 35                Não sei
# 36                    Sim
# 37                    Sim
# 38                Não sei
# 39                    Não
# 40                    Não
# 41                    Sim
# 42                Não sei
# 43                Não sei
# 44                    Sim
# 45                    Não
# 46                    Sim
# 47                Não sei
# 48                Não sei
# 49                    Não
#
# [50 rows x 22 columns]
